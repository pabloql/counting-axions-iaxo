# %%
#%matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from palettable.colorbrewer.sequential import YlOrRd_5
from Functions_Binned_Analysis import dNdw, IAXO, L_ES
import os
os.environ['PATH'] = os.environ['PATH'] + ':/Library/TeX/texbin'

plt.rcParams.update({
   "text.usetex":True,
   "font.size":30,
   "axes.formatter.limits":[-3,3],
   "axes.linewidth":3,
   "lines.linewidth":3,
   "xtick.top":True,
   "xtick.bottom":True,
   "ytick.left":True,
   "ytick.right":True,
   "xtick.minor.visible":True,
   "ytick.minor.visible":True,
   "xtick.direction":"in",
   "ytick.direction":"in",
   "xtick.major.width":2,
   "xtick.minor.width":1,
   "ytick.major.width":2,
   "ytick.minor.width":1,
   "xtick.major.size":10,
   "xtick.minor.size":5,
   "ytick.major.size":10,
   "ytick.minor.size":5,
   "figure.figsize":[21,9],
   "savefig.dpi":300,
   "savefig.transparent":True
})

reds = YlOrRd_5.mpl_colors

w_min = 0.0 # [keV]
w_max = 20.0 # [keV]
w = np.linspace(w_min,w_max,5000) # [keV]
g = 1e-11 # [GeV^-1]
exp = IAXO
L_source = L_ES
res_on = True
w_res = 100e-3 # [keV]

fig = plt.figure()
gs = gridspec.GridSpec(1,2,wspace=0)
axL = fig.add_subplot(gs[0,0])
axR = fig.add_subplot(gs[0,1])

#==============================================================================#

# 2-axion quasi-degenerate and "massless"
m2 = 1e-3 # [eV]
delta_m21_sq = (7e-7)**2 # [eV^2]
mixing = np.pi/4.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N,label=r'$\mathrm{Two\ quasi}$--$\mathrm{degenerate\ axions}$',color=reds[3])

# 1-axion "massive"
m2 = 1e-1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N,label=r'$\mathrm{Single\ massive\ axion}$',color="#0047AB",alpha=0.45)

# 1-axion "massless"
m2 = 1e-3 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N,label=r'$\mathrm{Single\ massless\ axion}$',color='gray',lw=5,alpha=0.5,zorder=0)


axL.set_xlim(left=0,right=15)
axL.set_xticks([0,3,6,9,12])
axL.set_ylim(bottom=0,top=0.3)
axL.tick_params(axis='x',which='major',pad=5)
axL.tick_params(axis='x',which='minor',pad=5)
axL.tick_params(axis='y',which='major',pad=5)
axL.tick_params(axis='y',which='minor',pad=5)
axL.set_xlabel(r"$\omega\ [\mathrm{keV}]$",fontsize=35,labelpad=8)
axL.set_ylabel(r"$\frac{1}{N_\gamma}\frac{\mathrm{d}N_\gamma}{\mathrm{d}\omega}\ [\mathrm{keV}^{-1}]$",fontsize=35,labelpad=15)
axL.legend(fontsize=25,frameon=True)

#==============================================================================#

# 2-axion hierarchical and one "massive"
m2 = 1.5e-2 # [eV]
delta_m21_sq = (1.5e-2)**2 # [eV^2]
mixing = np.pi/4.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N,label=r'$\mathrm{Two\ hierarchical\ axions}$',color=reds[3])

# 1-axion "massive"
m2 = 1e-1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N,label=r'$\mathrm{Single\ massive\ axion}$',color="#0047AB",alpha=0.45)

# 1-axion "massless"
m2 = 1e-3 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = dNdw(w,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],exp["t"],exp["eps_T"],exp["eps_D"],res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N,label=r'$\mathrm{Single\ massless\ axion}$',color='gray',lw=5,alpha=0.5,zorder=0)

axR.set_xlim(left=0,right=15)
axR.set_xticks([0,3,6,9,12,15])
axR.set_ylim(bottom=0,top=0.3)
axR.tick_params(axis='x',which='major',pad=5)
axR.tick_params(axis='x',which='minor',pad=5)
axR.set_xlabel(r"$\omega\ [\mathrm{keV}]$",fontsize=35,labelpad=8)
axR.legend(fontsize=25,frameon=True)
axR.tick_params(axis='y',labelleft=False)

#==============================================================================#

fig.savefig("../plots/Solar_spectra.pdf",bbox_inches="tight")
fig.savefig("../plots/Solar_spectra.png",bbox_inches="tight")
plt.show()

# %%
#%matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from palettable.colorbrewer.sequential import YlOrRd_5
from Functions_Binned_Analysis import SN_dNdw, IAXO, L_SN
import os
os.environ['PATH'] = os.environ['PATH'] + ':/Library/TeX/texbin'

plt.rcParams.update({
   "text.usetex":True,
   "font.size":30,
   "axes.formatter.limits":[-3,3],
   "axes.linewidth":3,
   "lines.linewidth":3,
   "xtick.top":True,
   "xtick.bottom":True,
   "ytick.left":True,
   "ytick.right":True,
   "xtick.minor.visible":True,
   "ytick.minor.visible":True,
   "xtick.direction":"in",
   "ytick.direction":"in",
   "xtick.major.width":2,
   "xtick.minor.width":1,
   "ytick.major.width":2,
   "ytick.minor.width":1,
   "xtick.major.size":10,
   "xtick.minor.size":5,
   "ytick.major.size":10,
   "ytick.minor.size":5,
   "figure.figsize":[21,9],
   "savefig.dpi":300,
   "savefig.transparent":True
})

reds = YlOrRd_5.mpl_colors

w_min = 0.0 # [MeV]
w_max = 1000.0 # [MeV]
w = np.linspace(w_min,w_max,5000) # [keV]
g = 1e-11 # [GeV^-1]
g_aN = 1.3e-9 
delta = 1.0
exp = IAXO
L_source = L_SN
eps = 0.95
res_on = True
w_res = 1.0 # [MeV]

fig = plt.figure()
gs = gridspec.GridSpec(1,2,wspace=0)
axL = fig.add_subplot(gs[0,0])
axR = fig.add_subplot(gs[0,1])

#==============================================================================#

# 2-axion quasi-degenerate and "massless"
m2 = 1e-1 # [eV]
delta_m21_sq = (1.5e-8)**2 # [eV^2]
mixing = np.pi/4.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N*1e2,label=r'$\mathrm{Two\ quasi}$--$\mathrm{degenerate\ axions}$',color=reds[3])

# 1-axion "massive"
m2 = 1e1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N*1e2,label=r'$\mathrm{Single\ massive\ axion}$',color="#0047AB",alpha=0.45)

# 1-axion "massless"
m2 = 1e-1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axL.plot(w,spectrum/N*1e2,label=r'$\mathrm{Single\ massless\ axion}$',color='gray',lw=8,alpha=0.5,zorder=0)

axL.set_xscale('log')
axL.set_xlim(left=1e0,right=1e3)
axL.set_xticks([1e0,1e1,1e2])
axL.tick_params(axis='x',pad=10)
axL.set_ylim(bottom=0,top=1.4)
axL.tick_params(axis='x',which='major',pad=10)
axL.tick_params(axis='x',which='minor',pad=10)
axL.tick_params(axis='y',which='major',pad=5)
axL.tick_params(axis='y',which='minor',pad=5)
axL.set_xlabel(r"$\omega\ [\mathrm{MeV}]$",fontsize=35,labelpad=8)
axL.set_ylabel(r"$\frac{1}{N_\gamma}\frac{\mathrm{d}N_\gamma}{\mathrm{d}\omega}\times 10^2\ [\mathrm{MeV}^{-1}]$",fontsize=35,labelpad=15)
axL.legend(fontsize=25,frameon=True)

#==============================================================================#

# 2-axion hierarchical and one "massive"
#m2 = 1e1 # [eV]
#delta_m21_sq = (1e1)**2 # [eV^2]
m2 = 1 # [eV]
delta_m21_sq = (1)**2 # [eV^2]
mixing = np.pi/4.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N*1e2,label=r'$\mathrm{Two\ hierarchical\ axions}$',color=reds[3])

# 1-axion "massive"
m2 = 1e1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N*1e2,label=r'$\mathrm{Single\ massive\ axion}$',color="#0047AB",alpha=0.45)

# 1-axion "massless"
m2 = 1e-1 # [eV]
delta_m21_sq = 0.0
mixing = 0.0
spectrum = SN_dNdw(w,g_aN,delta,g,m2,delta_m21_sq,mixing,exp["B"],exp["L"],L_source,exp["S"],eps,res_on=res_on,w_res=w_res)
N = np.trapezoid(spectrum,w)
axR.plot(w,spectrum/N*1e2,label=r'$\mathrm{Single\ massless\ axion}$',color='gray',lw=8,alpha=0.5,zorder=0)

axR.set_xscale('log')
axR.set_xlim(left=1e0,right=1e3)
axR.set_xticks([1e0,1e1,1e2,1e3])
axR.tick_params(axis='x',pad=10)
axR.set_ylim(bottom=0,top=1.4)
axR.tick_params(axis='x',which='major',pad=10)
axR.tick_params(axis='x',which='minor',pad=10)
axR.set_xlabel(r"$\omega\ [\mathrm{MeV}]$",fontsize=35,labelpad=8)
axR.legend(fontsize=25,frameon=True)
axR.tick_params(axis='y',labelleft=False)

#==============================================================================#

fig.savefig("../plots/SN_spectra.pdf",bbox_inches="tight")
fig.savefig("../plots/SN_spectra.png",bbox_inches="tight")
plt.show()
